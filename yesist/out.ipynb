# %%
import pandas as pd 
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.optimizers import Adam
from keras.models import load_model
from keras.layers import Dropout
xl=pd.read_csv(r"./w.csv",skiprows=14)
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

scaled = scaler.fit_transform(xl.loc[:, ~xl.columns.isin(['YEAR',"DOY",])])
inpp=pd.read_csv('input.csv', header=None, skiprows=1, nrows=1)
model = load_model("model.h5")
model.summary()
inp=[]
a1=float(inpp.iloc[0,0])
inp.append(a1)
a2=float(inpp.iloc[0,1])
inp.append(a2)
a3=float(inpp.iloc[0,2])
inp.append(a3)
a4=float(inpp.iloc[0,3])
inp.append(a4)
a5=float(inpp.iloc[0,4])
inp.append(a5)
a1=float(inpp.iloc[0,5])
inp.append(a1)
inputdata=np.array(inp)
inputdata.shape=(1,6)
input_data=scaler.transform(inputdata)
pred=model.predict(input_data)
inscaled=scaler.inverse_transform(pred)
print("THE predicted value is ",inscaled)
def get_weather_description(max_temp, min_temp, humidity, precipitation, surface_pressure, wind_speed):
    weather_description = []

    if max_temp >= 28:
        weather_description.append("warm")
    elif max_temp <= 15:
        weather_description.append("cold")
    else:
        weather_description.append("mild")


    if precipitation > 10:
        weather_description.append("heavyrain")
    elif precipitation > 5:
        weather_description.append("moderaterain")
    elif precipitation > 2:
        weather_description.append("lightrain")
    else:
        weather_description.append("dry")

    


    return "".join(weather_description)

# Taking inputs

max_temp, min_temp, humidity, precipitation, surface_pressure, wind_speed=inscaled[0,0],inscaled[0,1],inscaled[0,2],inscaled[0,3],inscaled[0,4],inscaled[0,5]
# Get the weather description
max
weather_desc = get_weather_description(max_temp, min_temp, humidity, precipitation, surface_pressure, wind_speed)

# Print the weather description

print("The weather is: ", weather_desc)
# Out:
# 2023-09-03 12:01:20.641644: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-09-03 12:01:23.974274: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-09-03 12:01:23.986588: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-03 12:01:32.058772: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 8)                 56
#
#  dense_1 (Dense)             (None, 8)                 72
#
# ...

# %%
# Out:
# 706.0
# 705.0
# 703.0
# 702.0

# %%
# Out:
# Arduino not found.

# %%
import serial
import time
import serial.tools.list_ports
ports = list(serial.tools.list_ports.comports())
for p in ports:
    x=str(p)

z=x.split(' ')


# Replace 'COM7' with the appropriate serial port for your Arduino
arduino = serial.Serial(z[0], 9600, timeout=4)


def send_command(command):
    arduino.write(command.encode())  # Send the command as bytes
    time.sleep(0.1)  # Wait for Arduino to process

# Specify the number of times to send each command
num_repeats = 4  # Change this value as needed

# Send commands to the Arduino a certain number of times
for i in range(num_repeats):
    moist=arduino.readline().decode('utf-8').strip()

    moist=float(moist)
    print(moist)
    
    if(weather_desc=="warmdry"):
        if(moist<300):
            continue
        elif(moist>300 and moist<400):
            send_command('A')  # Send command A
            time.sleep(5)  # Wait for a second before sending the next command
            send_command('B')  # Send command B
            time.sleep(1)  # Wait for a second before sending the next command
        elif(moist>400 and moist<700):
            send_command('A')  # Send command A
            time.sleep(10)  # Wait for a second before sending the next command
            send_command('B')  # Send command B
            time.sleep(1)  # Wait for a second before sending the next command
        elif(moist>700):
            send_command('A')  # Send command A
            time.sleep(15)  # Wait for a second before sending the next command
            send_command('B')  # Send command B
            time.sleep(1)  # Wait for a second before sending the next command
            
    elif(weather_desc=="warmlightrain"):
        if(moist<300):
            continue
        elif(moist>300 and moist<400):
            send_command('A')  # Send command A
            time.sleep(5)  # Wait for a second before sending the next command
            send_command('B')  # Send command B
            time.sleep(1)  # Wait for a second before sending the next command
        elif(moist>400 and moist<700):
            send_command('A')  # Send command A
            time.sleep(8)  # Wait for a second before sending the next command
            send_command('B')  # Send command B
            time.sleep(1)  # Wait for a second before sending the next command
        elif(moist>700):
            send_command('A')  # Send command A
            time.sleep(12) 
            if(i==3):
                send_command('B')# Wait for a second before sending the next command
            send_command('B')  # Send command B
            time.sleep(1)  # Wait for a second before sending the next command
            
    elif(weather_desc=="warmmoderaterain"):
        if(moist<300):
            continue
            time.sleep(1)  # Wait for a second before sending the next command
        elif(moist>300 and moist<400):
            send_command('A')  # Send command A
            time.sleep(3)  # Wait for a second before sending the next command
            send_command('B')  # Send command B
            time.sleep(1)  # Wait for a second before sending the next command
        elif(moist>400 and moist<700):
            send_command('A')  # Send command A
            time.sleep(7)  # Wait for a second before sending the next command
            send_command('B')  # Send command B
            time.sleep(1)  # Wait for a second before sending the next command
        elif(moist>700):
            send_command('A')  # Send command A
            time.sleep(10) 
            if(i==3):
                send_command('B')# Wait for a second before sending the next command
            send_command('B')  # Send command B
            time.sleep(1)  # Wait for a second before sending the next command
            
    elif(weather_desc=="warmheavyrain"):
         continue


    elif(weather_desc=="milddry"):
        if(moist<300):
            continue
        elif(moist>300 and moist<400):
            send_command('A')  # Send command A
            time.sleep(5)  # Wait for a second before sending the next command
            send_command('B')  # Send command B
            time.sleep(1)  # Wait for a second before sending the next command
        elif(moist>400 and moist<700):
            send_command('A')  # Send command A
            time.sleep(10)  # Wait for a second before sending the next command
            send_command('B')  # Send command B
            time.sleep(1)  # Wait for a second before sending the next command
        elif(moist>700):
            send_command('A')  # Send command A
            time.sleep(15)  # Wait for a second before sending the next command
            send_command('B')  # Send command B
            time.sleep(1)  # Wait for a second before sending the next command
            
    elif(weather_desc=="mildlightrain"):
        if(moist<300):
            continue
        elif(moist>300 and moist<400):
            send_command('A')  # Send command A
            time.sleep(5)  # Wait for a second before sending the next command
            send_command('B')  # Send command B
            time.sleep(1)  # Wait for a second before sending the next command
        elif(moist>400 and moist<700):
            send_command('A')  # Send command A
            time.sleep(8)  # Wait for a second before sending the next command
            send_command('B')  # Send command B
            time.sleep(1)  # Wait for a second before sending the next command
        elif(moist>700):
            send_command('A')  # Send command A
            time.sleep(12)  # Wait for a second before sending the next command
            send_command('B')  # Send command B
            time.sleep(1)  # Wait for a second before sending the next command
            
    elif(weather_desc=="mildmoderaterain"):
        if(moist<300):
            scontinue
        elif(moist>300 and moist<400):
            send_command('A')  # Send command A
            time.sleep(3)  # Wait for a second before sending the next command
            send_command('B')  # Send command B
            time.sleep(1)  # Wait for a second before sending the next command
        elif(moist>400 and moist<700):
            send_command('A')  # Send command A
            time.sleep(7)  # Wait for a second before sending the next command
            send_command('B')  # Send command B
            time.sleep(1)  # Wait for a second before sending the next command
        elif(moist>700):
            send_command('A')  # Send command A
            time.sleep(10)  # Wait for a second before sending the next command
            send_command('B')  # Send command B
            time.sleep(1)  # Wait for a second before sending the next command
            
    elif(weather_desc=="mildheavyrain"):
         continue


    elif(weather_desc=="colddry"):
        if(moist<300):
            continue
        elif(moist>300 and moist<400):
            send_command('A')  # Send command A
            time.sleep(8)  # Wait for a second before sending the next command
            send_command('B')  # Send command B
            time.sleep(1)  # Wait for a second before sending the next command
        elif(moist>400 and moist<700):
            send_command('A')  # Send command A
            time.sleep(12)  # Wait for a second before sending the next command
            send_command('B')  # Send command B
            time.sleep(1)  # Wait for a second before sending the next command
        elif(moist>700):
            send_command('A')  # Send command A
            time.sleep(15)  # Wait for a second before sending the next command
            send_command('B')  # Send command B
            time.sleep(1)  # Wait for a second before sending the next command
            
    elif(weather_desc=="coldlightrain"):
        if(moist<300):
            continue
        elif(moist>300 and moist<400):
            send_command('A')  # Send command A
            time.sleep(5)  # Wait for a second before sending the next command
            send_command('B')  # Send command B
            time.sleep(1)  # Wait for a second before sending the next command
        elif(moist>400 and moist<700):
            send_command('A')  # Send command A
            time.sleep(10)  # Wait for a second before sending the next command
            send_command('B')  # Send command B
            time.sleep(1)  # Wait for a second before sending the next command
        elif(moist>700):
            send_command('A')  # Send command A
            time.sleep(12)  # Wait for a second before sending the next command
            send_command('B')  # Send command B
            time.sleep(1)  # Wait for a second before sending the next command
            
    elif(weather_desc=="coldmoderaterain"):
        if(moist<300):
            continue
        elif(moist>300 and moist<400):
            send_command('A')  # Send command A
            time.sleep(3)  # Wait for a second before sending the next command
            send_command('B')  # Send command B
            time.sleep(1)  # Wait for a second before sending the next command
        elif(moist>400 and moist<700):
            send_command('A')  # Send command A
            time.sleep(8)  # Wait for a second before sending the next command
            send_command('B')  # Send command B
            time.sleep(1)  # Wait for a second before sending the next command
        elif(moist>700):
            send_command('A')  # Send command A
            time.sleep(10)  # Wait for a second before sending the next command
            send_command('B')  # Send command B
            time.sleep(1)  # Wait for a second before sending the next command
            
    elif(weather_desc=="coldheavyrain"):
         continue


send_command('B')
arduino.close()  # Close the serial connection
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 26
#      23 for i in range(num_repeats):
#      24     moist=arduino.readline().decode('utf-8').strip()
# ---> 26     moist=float(moist)
#      27     print(moist)
#      29     if(weather_desc=="warmdry"):
#
# ValueError: could not convert string to float: ''
